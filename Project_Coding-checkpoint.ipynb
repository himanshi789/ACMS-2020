# %% [markdown]
# # Twitter analysis for Last Mile Delivery

# %%
import numpy as np 
import pandas as pd 
import re  
import nltk 
# %matplotlib inline
nltk.download('stopwords')  
from nltk.corpus import stopwords 
import seaborn as sns
from textblob import TextBlob, Word, Blobber
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\guh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data=pd.read_csv('tweets.csv')
data.head()
# Out:
#    Unnamed: 0                                              ttext  \
# 0           1  AhmedBaba_: Make no mistake about what this is...
# 1           2  AhmedBaba_: Make no mistake about what this is...
# 2           3  AhmedBaba_: In the Oval Office, President Trum...
# 3           4  AhmedBaba_: In the Oval Office, President Trum...
# 4           5  AhmedBaba_: In the Oval Office, President Trum...
#
#                   date  isretweet  retweetcount  favoritecount  score  \
# 0  2020-04-24 17:28:54       True           158              0     -1
# 1  2020-04-24 17:28:53       True           158              0     -1
# 2  2020-04-24 17:28:51       True            73              0     -1
# 3  2020-04-24 17:28:45       True            73              0     -1
# 4  2020-04-24 17:28:07       True            73              0     -1
#
#         city country  duplicate
# 0  Delhi NCR   India      False
# 1  Delhi NCR   India       True
# 2  Delhi NCR   India      False
# 3  Delhi NCR   India       True
# 4  Delhi NCR   India       True

# %%
# CLEANING OF DATASET
def clean_tweet(tweet): 
        ''' 
        Utility function to clean tweet text by removing links, special characters 
        using simple regex statements. 
        '''
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split()) 

# CATEGORISE THE DATA AS PER THEIR SENTIMENTS    
def get_tweet_sentiment( tweet): 
        # create TextBlob object of passed tweet text 
        analysis = TextBlob(clean_tweet(tweet))
        # set sentiment 
        if analysis.sentiment.polarity > 0: 
            return 'positive'
        elif analysis.sentiment.polarity == 0: 
            return 'neutral'
        else: 
            return 'negative'

# READ THE DATASET
data=pd.read_csv('Global10000_4May.csv')

data1=pd.DataFrame(data['ttext'])
df=data['ttext']
data1['sentiments']= [get_tweet_sentiment(t)for t in df]
print(data1) # displays a cleaned dataset
# Out:
#                                                   ttext sentiments
# 0                            @MrBeastYT Amazon delivery    neutral
# 1     RT @B16_A1: Thank the lord for Amazon essentia...    neutral
# 2      Thank the lord for Amazon essential delivery..      neutral
# 3     Ordered a cheap table and chairs for our balco...   positive
# 4     @PeachyKeenGreat @ADAMWTF1 @shaunking @amazon ...   positive
# ...                                                 ...        ...
# 9995  RT @DBLTAPesports: No one: \n\nAmazon Prime De...    neutral
# 9996  RT @DBLTAPesports: No one: \n\nAmazon Prime De...    neutral
# 9997  RT @DBLTAPesports: No one: \n\nAmazon Prime De...    neutral
# 9998  @r_aguc @MrPuli Like saravana stores they have...    neutral
# 9999  RT @DBLTAPesports: No one: \n\nAmazon Prime De...    neutral
#
# [10000 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer  
tfidfconverter = TfidfVectorizer(max_features=2000, min_df=5, max_df=0.7, stop_words=stopwords.words('english'))  
X = tfidfconverter.fit_transform(processed_tweets).toarray()

from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
 
 
from sklearn.ensemble import RandomForestClassifier
text_classifier = RandomForestClassifier(n_estimators=100, random_state=0)  
text_classifier.fit(X_train, y_train)
 
 
predictions = text_classifier.predict(X_test)
 
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
X = data.iloc[:,1].values  
y = data1.iloc[:,-1].values

processed_tweets = []
 
for tweet in range(0, len(X)):  
    # Remove all the special characters
    processed_tweet = re.sub(r'\W', ' ', str(X[tweet]))
 
    # remove all single characters
    processed_tweet = re.sub(r'\s+[a-zA-Z]\s+', ' ', processed_tweet)
 
    # Remove single characters from the start
    processed_tweet = re.sub(r'\^[a-zA-Z]\s+', ' ', processed_tweet) 
 
    # Substituting multiple spaces with single space
    processed_tweet= re.sub(r'\s+', ' ', processed_tweet, flags=re.I)
 
    # Removing prefixed 'b'
    processed_tweet = re.sub(r'^b\s+', '', processed_tweet)
 
    # Converting to Lowercase
    processed_tweet = processed_tweet.lower()
 
    processed_tweets.append(processed_tweet)
    
    
print(processed_tweets)
# Out:
# [' mrbeastyt amazon delivery', 'rt b16_a1 thank the lord for amazon essential delivery ', 'thank the lord for amazon essential delivery ', 'ordered cheap table and chairs for our balcony on amazon delivery delayed checked location of seller germany fml ', ' peachykeengreat adamwtf1 shaunking amazon it would be great if amazon stopped delivery to haters', ' robin_blue19 it extends to the citizenry have you seen the comments under the news about amazon workers striki ', 'rt vicky_walters my paperback has arrived and its so pretty if you fancy copy you can order it from the book depository with fre', 'rt wsj dont wait for delayed amazon delivery small businesses around the country are turning around orders fast ', 'rt giftideas17 dont have an outdoor tap but im desperate to powerwash my paving so found this nifty little gadget which didnt k', 'rt trillxlauren amazon prime really left amp said fuck yall delivery date whenever ', 'rt giftideas17 dont have an outdoor tap but im desperate to powerwash my paving so found this nifty little gadget which didnt k', 'rt shade510 my wife does quite bit of online shopping so much so she included the amazon delivery guy in the family portrait above t', 'rt giftideas17 dont have an outdoor tap but im desperate to powerwash my paving so found this nifty little gadget which didnt k', 'rt giftideas17 dont have an outdoor tap but im desperate to powerwash my paving so found this nifty little gadget which didnt k', 'i dont have an outdoor tap but im desperate to powerwash my paving so found this nifty little gadget which d ', ' dd0llars our apologies for the longer than expected wait may we know the current status and delivery date as show ', ' dandribbler hey we would ask not to post personal information were temporarily experiencing longer than usual ', 'rt joeyoungcomedy if ran amazon would be better than jeff bezos not only because id give all my delivery drivers health insurance ', ' helenkennedy spiroagnewghost its personal he believes usps gave amazon too sweet deal for last mile delivery ', 'rt joeyoungcomedy if ran amazon would be better than jeff bezos not only because id give all my delivery drivers health insurance ', 'rt shade510 my wife does quite bit of online shopping so much so she included the amazon delivery guy in the family portrait above t', 'rt shade510 my wife does quite bit of online shopping so much so she included the amazon delivery guy in the family portrait above t', ' amazonhelp any update when will amazon restart the delivery to 182202 it was stopped in aug 2019 not related ', ' mkbhd amazon delivery tracking said guaranteed between 10 11 45 driver arrived at complex at 9 30am literally sp ', ' corsair thank you for giving me 15 delivery charge at checkout after claiming free shipping you got me to fi ', ' dhlexpressuk hi who can contact about dhl delivery generated in germany attempted to be delivered in the amaz ', ' arvindkejriwal msisodia aapkagopalrai satyendarjain humbly request you that please take option of home deliver ', 'dell wd19 180w docking station 130w power delivery usb hdmi dual displayport black ', ' arunava anujachauhan yes it odd bcoz amazon has sturdy logistics base of its own and for prime members deli ', ' mouthnoize ve been to doing 10 to 12 hours on the amazon prime delivery scene m looking forward to staying home lol', 'rt awscloud learn how to lower tco amp increase query performance by running hive on spark in amazon emr ', ' bryanjlevek lol my 16yo is learning that lesson ordered him hoodie he wanted not from amazon but website sai ', ' chrisserres any updates on ebt also know pickup is free at walmart but there are still delivery fees with ', ' gilllindsay10 hi gill you can contact the seller directly through your order here ', 'rt awscloud learn how to lower tco amp increase query performance by running hive on spark in amazon emr ', 'i want to ask mohfw_india arvindkejriwal pmoindia if revenue is necessary alcohol liquid wine bear why  ...

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[ 155   29   15]
#  [   2 1469   12]
#  [  12   53  253]]

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.78      0.84       199
#      neutral       0.95      0.99      0.97      1483
#     positive       0.90      0.80      0.85       318
#
#     accuracy                           0.94      2000
#    macro avg       0.92      0.86      0.89      2000
# weighted avg       0.94      0.94      0.94      2000

# %%
print(accuracy_score(y_test, predictions))
# Out:
# 0.9385

# %%
data=pd.read_csv('tweets.csv')
data1=pd.DataFrame(data['ttext'])
df=data['ttext']
data1['sentiments']= [get_tweet_sentiment(t)for t in df]
n_records = len(data1.index)
n_sent_pos = len(data1[data1['sentiments'] == 'positive'])
n_sent_neg = len(data1[data1['sentiments'] == 'negative'])
n_sent_neu = len(data1[data1['sentiments'] == 'neutral'])
print("Total records: ",n_records)
print("Positive: ",n_sent_pos)
print("Negative: ",n_sent_neg)
print("Neutral: ",n_sent_neu)
sns.countplot(x='sentiments', data=data1)
# Out:
# Total records:  5000
# Positive:  2047
# Negative:  953
# Neutral:  2000

# %%
data=pd.read_csv('Global10000_4May.csv')
data1=pd.DataFrame(data['ttext'])
df=data['ttext']
data1['sentiments']= [get_tweet_sentiment(t)for t in df]
n_records = len(data1.index)
n_sent_pos = len(data1[data1['sentiments'] == 'positive'])
n_sent_neg = len(data1[data1['sentiments'] == 'negative'])
n_sent_neu = len(data1[data1['sentiments'] == 'neutral'])
print("Global total records: ",n_records)
print("Global  positive: ",n_sent_pos)
print("Global negative: ",n_sent_neg)
print("Global neutral: ",n_sent_neu)
sns.countplot(x='sentiments', data=data1)
# Out:
# Global total records:  10000
# Global  positive:  1521
# Global negative:  1135
# Global neutral:  7344

# %%
data=pd.read_csv('delhi_4may.csv')
data1=pd.DataFrame(data['ttext'])
df=data['ttext']
data1['sentiments']= [get_tweet_sentiment(t)for t in df]
n_records = len(data1.index)
n_sent_pos = len(data1[data1['sentiments'] == 'positive'])
n_sent_neg = len(data1[data1['sentiments'] == 'negative'])
n_sent_neu = len(data1[data1['sentiments'] == 'neutral'])
print("DELHI total records: ",n_records)
print("DELHI  positive: ",n_sent_pos)
print("DELHI negative: ",n_sent_neg)
print("DELHI neutral: ",n_sent_neu)
# Out:
# DELHI total records :  141
# DELHI  positive :  26
# DELHI negative :  50
# DELHI neutral :  65

# %%
data=pd.read_csv('mumbai_4_May.csv')
data1=pd.DataFrame(data['ttext'])
df=data['ttext']
data1['sentiments']= [get_tweet_sentiment(t)for t in df]
n_records = len(data1.index)
n_sent_pos = len(data1[data1['sentiments'] == 'positive'])
n_sent_neg = len(data1[data1['sentiments'] == 'negative'])
n_sent_neu = len(data1[data1['sentiments'] == 'neutral'])
print("MUMBAI total records: ",n_records)
print("MUMBAI  positive: ",n_sent_pos)
print("MUMBAI negative: ",n_sent_neg)
print("MUMBAI neutral: ",n_sent_neu)
sns.countplot(x='sentiments', data=data1)
# Out:
# MUMBAI total records:  113
# MUMBAI  positive:  41
# MUMBAI negative:  14
# MUMBAI neutral:  58

# %%
data=pd.read_csv('bangalore_4_May.csv')
data1=pd.DataFrame(data['ttext'])
df=data['ttext']
data1['sentiments']= [get_tweet_sentiment(t)for t in df]
n_records = len(data1.index)
n_sent_pos = len(data1[data1['sentiments'] == 'positive'])
n_sent_neg = len(data1[data1['sentiments'] == 'negative'])
n_sent_neu = len(data1[data1['sentiments'] == 'neutral'])
print("BANGALORE total records: ",n_records)
print("BANGALORE  positive: ",n_sent_pos)
print("BANGALORE negative: ",n_sent_neg)
print("BANGALORE neutral: ",n_sent_neu)
sns.countplot(x='sentiments', data=data1)
# Out:
# BANGALORE total records:  113
# BANGALORE  positive:  41
# BANGALORE negative:  14
# BANGALORE neutral:  58

# %%
data=pd.read_csv('Kerala_4_May.csv')
data1=pd.DataFrame(data['ttext'])
df=data['ttext']
data1['sentiments']= [get_tweet_sentiment(t)for t in df]
n_records = len(data1.index)
n_sent_pos = len(data1[data1['sentiments'] == 'positive'])
n_sent_neg = len(data1[data1['sentiments'] == 'negative'])
n_sent_neu = len(data1[data1['sentiments'] == 'neutral'])
print("KERALA total records: ",n_records)
print("KERALA  positive: ",n_sent_pos)
print("KERALA negative: ",n_sent_neg)
print("KERALA neutral: ",n_sent_neu)
sns.countplot(x='sentiments', data=data1)
# Out:
# KERALA total records:  15
# KERALA  positive:  5
# KERALA negative:  1
# KERALA neutral:  9

# %%
data=pd.read_csv('haryana_4_May.csv')
data1=pd.DataFrame(data['ttext'])
df=data['ttext']
data1['sentiments']= [get_tweet_sentiment(t)for t in df]
n_records = len(data1.index)
n_sent_pos = len(data1[data1['sentiments'] == 'positive'])
n_sent_neg = len(data1[data1['sentiments'] == 'negative'])
n_sent_neu = len(data1[data1['sentiments'] == 'neutral'])
print("Haryana total records: ",n_records)
print("Haryana positive: ",n_sent_pos)
print("Haryana negative: ",n_sent_neg)
print("Haryana neutral: ",n_sent_neu)
sns.countplot(x='sentiments', data=data1)
# Out:
# Haryana total records:  131
# Haryana positive:  43
# Haryana negative:  35
# Haryana neutral:  53

# %%
data=pd.read_csv('uttarpradesh_4_May.csv')
data1=pd.DataFrame(data['ttext'])
df=data['ttext']
data1['sentiments']= [get_tweet_sentiment(t)for t in df]
n_records = len(data1.index)
n_sent_pos = len(data1[data1['sentiments'] == 'positive'])
n_sent_neg = len(data1[data1['sentiments'] == 'negative'])
n_sent_neu = len(data1[data1['sentiments'] == 'neutral'])
print("Uttar Pradesh total records: ",n_records)
print("Uttar Pradesh  positive: ",n_sent_pos)
print("Uttar Pradesh negative: ",n_sent_neg)
print("Uttar Pradesh neutral: ",n_sent_neu)
sns.countplot(x='sentiments', data=data1)
# Out:
# Uttar Pradesh total records:  7
# Uttar Pradesh  positive:  6
# Uttar Pradesh negative:  0
# Uttar Pradesh neutral:  1
